# %%
import pandas as pd
s1 = pd.Series([2, 3, 5, 6, 72])
s1
# Out:
# 0     2
# 1     3
# 2     5
# 3     6
# 4    72
# dtype: int64

# %%
s1= pd.Series([2, 3, 5, 6, 72], index=['a', 'b', 'c', 'd', 'e'])
s1
# Out:
# a     2
# b     3
# c     5
# d     6
# e    72
# dtype: int64

# %%
pd.Series({'k1':10, 'k2':66, 'k3':9, 'k4':3})
# Out:
# k1    10
# k2    66
# k3     9
# k4     3
# dtype: int64

# %%
pd.Series({'k1':10, 'k2':66, 'k3':9, 'k4':3},index= ['k1', 'h6', 'k3', 'k4'])
# Out:
# k1    10.0
# h6     NaN
# k3     9.0
# k4     3.0
# dtype: float64

# %%
s1[:'c']
# Out:
# a    2
# b    3
# c    5
# dtype: int64

# %%
r1 = pd.DataFrame({"Name":['Rio', 'Sam', 'Ian', 'Tia'], "Age": [11, 31, 20, 24], "Gender":['M', 'F', 'M', 'F']}, index=[1, 2, 3, 4])
r1
# Out:
#   Name  Age Gender
# 1  Rio   11      M
# 2  Sam   31      F
# 3  Ian   20      M
# 4  Tia   24      F

# %%
# Out:
# ...
#
# ...
