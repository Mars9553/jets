# %%
l1  = [23, 4, 5, 75, 26, 9, 35, 98, 3, 16, 82, 65, 22, 11,]

# %%
list_final_new = list(map(lambda x: x*3, l1))

# %%
list_final_new
# Out:
# [69, 12, 15, 225, 78, 27, 105, 294, 9, 48, 246, 195, 66, 33]

# %%
from functools import reduce

# %%
reduce(lambda x,y : x*y, l1)
# Out:
# 1714402869379200000
