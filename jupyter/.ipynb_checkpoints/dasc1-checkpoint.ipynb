# %%
a = 13
b = 43

# %%
a, b
# Out:
# (13, 43)

# %%
a*b
# Out:
# 559

# %%
a/b
# Out:
# 0.3023255813953488

# %%
r = 283
s = 827

# %%
r < s
# Out:
# True

# %%
r > s
# Out:
# False

# %%
r == s
# Out:
# False

# %%
a = True
b = False

# %%
a & b
# Out:
# False

# %%
a | b
# Out:
# True

# %%
b | a
# Out:
# True

# %%
b | b
# Out:
# False

# %%
a | a
# Out:
# True
