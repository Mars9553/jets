# %%
import pandas as pd

# %%
iris_file_path = "C:\\Users\\hp\\Desktop\\kaggle\\melb_data.csv\\melb_data.csv"
df = pd.read_csv(iris_file_path)
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
ad = df.dropna(axis = 0)

# %%
feature = ['YearBuilt','Rooms', 'Car', 'Bedroom2', 'Price', 'Landsize']
x = df[feature]
x.describe()
# Out:
#          YearBuilt         Rooms           Car      Bedroom2         Price  \
# count  8205.000000  13580.000000  13518.000000  13580.000000  1.358000e+04
# mean   1964.684217      2.937997      1.610075      2.914728  1.075684e+06
# std      37.273762      0.955748      0.962634      0.965921  6.393107e+05
# min    1196.000000      1.000000      0.000000      0.000000  8.500000e+04
# 25%    1940.000000      2.000000      1.000000      2.000000  6.500000e+05
# 50%    1970.000000      3.000000      2.000000      3.000000  9.030000e+05
# 75%    1999.000000      3.000000      2.000000      3.000000  1.330000e+06
# max    2018.000000     10.000000     10.000000     20.000000  9.000000e+06
#
#             Landsize
# count   13580.000000
# mean      558.416127
# std      3990.669241
# min         0.000000
# 25%       177.000000
# 50%       440.000000
# 75%       651.000000
# max    433014.000000

# %%
from sklearn.tree import DecisionTreeRegressor
models = DecisionTreeRegressor(random_state =1)

# %%
models.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
import pandas as pd
import matplotlib.pylab as plt
file_path = "C:\\Users\\hp\\Desktop\\kaggle\\melb_data.csv\\melb_data.csv"
data = pd.read_csv(file_path)
filter_data = data.dropna(axis = 0)

# %%
y = filter_data.Price
feature = ['YearBuilt','Rooms', 'Car', 'Bedroom2', 'Price', 'Landsize']
X = filter_data[feature]

# %%
from sklearn.tree import DecisionTreeRegressor
models = DecisionTreeRegressor()
models.fit(X, y)
pred= models.predict(X)

# %%
plt.scatter(pr, y)
